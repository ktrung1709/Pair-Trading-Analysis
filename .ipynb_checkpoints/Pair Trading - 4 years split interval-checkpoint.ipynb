# %%
# %%HTML
# <h1>Import Data</h1>
# Out:
# <h1>Import Data</h1>

# %%
import pandas as pd
df1 = pd.read_csv('./data/210730_HNX_ALL.txt', sep = ',')
df2 = pd.read_csv('./data/210730_HOSE_ALL.txt', sep = ',')

frames = [df1, df2]
df = pd.concat(frames, ignore_index = True)
df.head()
# Out:
#   <Ticker>  <DTYYYYMMDD>  <Open>  <High>  <Low>  <Close>  <Volume>
# 0      AAV      20210730    12.4    12.4   12.1     12.4    166400
# 1      ABT      20210730    26.0    27.2   26.0     27.1      1207
# 2      ACM      20210730     2.3     2.4    2.3      2.4    592463
# 3      ADC      20210730    21.5    21.5   21.5     21.5         0
# 4      ALT      20210730    12.7    12.7   12.7     12.7         0

# %%
# %%HTML
# <h1>Extract Data</h1>
# Out:
# <h1>Extract Data</h1>

# %%
# Remove redundant characters
df.columns=df.columns.str.replace('[<,>]','', regex=True)
df.head()

# Drop duplicate records
df_modified = df.drop_duplicates(subset = ['Ticker', 'DTYYYYMMDD'], keep = 'first')

# Change date data type
df_modified["DTYYYYMMDD"] = pd.to_datetime(df_modified["DTYYYYMMDD"], format='%Y%m%d')
df_modified.head()
# Out:
#   Ticker DTYYYYMMDD  Open  High   Low  Close  Volume
# 0    AAV 2021-07-30  12.4  12.4  12.1   12.4  166400
# 1    ABT 2021-07-30  26.0  27.2  26.0   27.1    1207
# 2    ACM 2021-07-30   2.3   2.4   2.3    2.4  592463
# 3    ADC 2021-07-30  21.5  21.5  21.5   21.5       0
# 4    ALT 2021-07-30  12.7  12.7  12.7   12.7       0

# %%
#Pivot the table
pivot = df_modified.pivot(index='DTYYYYMMDD', columns='Ticker', values = 'Close')
pivot.head()
# Out:
# Ticker        AAA    AAM  AAT  AAV  ABS     ABT    ACB    ACC    ACL  ACM  \
# DTYYYYMMDD
# 2012-01-03  2.950  8.336  NaN  NaN  NaN  13.371  5.760  5.259  5.411  NaN
# 2012-01-04  2.976  8.487  NaN  NaN  NaN  13.409  5.760  5.289  5.349  NaN
# 2012-01-05  2.950  8.374  NaN  NaN  NaN  13.669  5.939  5.053  5.349  NaN
# 2012-01-06  2.925  8.374  NaN  NaN  NaN  13.036  5.819  5.289  5.349  NaN
# 2012-01-09  2.950  8.374  NaN  NaN  NaN  13.036  5.790  5.289  5.349  NaN
#
# Ticker      ...  VTJ     VTL    VTO    VTV    VXB    WCS  WSS  X20  YBM  YEG
# DTYYYYMMDD  ...
# 2012-01-03  ...  NaN  15.657  1.707  1.224  3.521  14.96  3.1  NaN  NaN  NaN
# 2012-01-04  ...  NaN  15.657  1.707  1.269  3.521  14.96  2.9  NaN  NaN  NaN
# 2012-01-05  ...  NaN  15.657  1.666  1.269  3.298  14.96  2.9  NaN  NaN  NaN
# 2012-01-06  ...  NaN  15.657  1.626  1.269  3.164  14.96  2.8  NaN  NaN  NaN
# 2012-01-09  ...  NaN  15.657  1.666  1.291  3.030  14.96  2.8  NaN  NaN  NaN
#
# [5 rows x 750 columns]

# %%
industry = pd.read_excel('./data/industry.xlsx', index_col=0)
industry.head()
# Out:
#                         Value
# Ticker
# AAA                      Nhựa
# AAM                  Thủy sản
# AAT                Thương mại
# AAV                Thương mại
# ABS     Sản xuất - Kinh Doang

# %%
# %%HTML
# <h1>Filter Data</h1>
# Out:
# <h1>Filter Data</h1>

# %%
# %%HTML
# <h3>We will slice the dataframe to small intervals of 3 months</h3>
# Out:
# <h3>We will slice the dataframe to small intervals of 3 months</h3>

# %%
data_list = []

import datetime
from datetime import timedelta

start_date = datetime.date(2015, 1, 1)
end_date = start_date

while end_date.year != 2019:
    end_date = start_date + datetime.timedelta(days=90)
    quarter = pivot.loc[start_date:end_date]
    data_list.append(quarter)
    start_date = end_date

# %%
# %%HTML
# <h1>Clean Data</h1>
# Out:
# <h1>Clean Data</h1>

# %%
def find_cointegrated_pairs(data, significance=0.05):
    # This function is from https://www.quantopian.com/lectures/introduction-to-pairs-trading
    n = data.shape[1]
    score_matrix = np.zeros((n, n))
    pvalue_matrix = np.ones((n, n))
    keys = data.keys()
    pairs = []
    for i in range(1):
        for j in range(i+1, n):
            S1 = data[keys[i]]            
            S2 = data[keys[j]]
            result = coint(S1, S2)
            score = result[0]
            pvalue = result[1]
            score_matrix[i, j] = score
            pvalue_matrix[i, j] = pvalue
            if pvalue < significance:
                pairs.append((keys[i], keys[j]))
    return score_matrix, pvalue_matrix, pairs

# %%
def clean_data_func(data):
    # We shall remove all the columns with more than 20% of missing data
    missing_percentage = data.isnull().mean().sort_values(ascending=False)
    dropped_list = sorted(list(missing_percentage[missing_percentage > 0.2].index))
    data.drop(labels=dropped_list, axis=1, inplace=True)
    
    #Fill the remaining missing values with already available values
    data = data.fillna(method='ffill')
    data = data.fillna(method='bfill')
    return data

# %%
def returns_func(data):
    #Calculate percentage returns and create a data frame
    returns = data.pct_change()

    returns.replace([np.inf, -np.inf], np.nan, inplace=True)
    returns.dropna(inplace=True)
    
    return returns

# %%
def mean_returns_func(data):
    #Calculate mean returns and create a data frame
    mean_returns = data.pct_change().mean()*len(data)
    mean_returns = pd.DataFrame(mean_returns)
    mean_returns.columns = ['mean returns']

    #Calculate the volatility
    mean_returns['volatility'] = data.pct_change().std()*np.sqrt(len(data))
    
    return mean_returns

# %%
def industry_func(industry, mean_returns):
    industry_filter = industry
    for i in industry.index:
        if i not in mean_returns.index:
            industry_filter = industry_filter.drop(i)
    
    return industry_filter

# %%
def extract_pair(returns, clustered):
    clustered_series = pd.Series(index=returns.columns, data=clustered.flatten())
#     clustered_series_all = pd.Series(index=returns.columns, data=clustered.flatten())
    clustered_series = clustered_series[clustered_series != -1]
    
    CLUSTER_SIZE_LIMIT = 9999
    counts = clustered_series.value_counts()
    ticker_count_reduced = counts[(counts>1) & (counts<=CLUSTER_SIZE_LIMIT)]

    cluster_dict = {}
    for i, which_clust in enumerate(ticker_count_reduced.index):
        tickers = clustered_series[clustered_series == which_clust].index
        score_matrix, pvalue_matrix, pairs = find_cointegrated_pairs(returns[tickers])
        cluster_dict[which_clust] = {}
        cluster_dict[which_clust]['score_matrix'] = score_matrix
        cluster_dict[which_clust]['pvalue_matrix'] = pvalue_matrix
        cluster_dict[which_clust]['pairs'] = pairs
    
    pairs = []
    for clust in cluster_dict.keys():
        pairs.extend(cluster_dict[clust]['pairs'])
    
    return pairs

# %%
def pair_rating(pairs, pair_dict):
    for pair in pairs:
        if pair in pair_dict:
            pair_dict[pair] = pair_dict[pair] + 1
        else:
            pair_dict[pair] = 1

# %%
import numpy as np
from sklearn import preprocessing
from sklearn.cluster import DBSCAN
from statsmodels.tsa.stattools import coint

pd.options.mode.chained_assignment = None

pair_dict = {}

for data in data_list:
    
    data = clean_data_func(data)
    returns = returns_func(data)
    data1 = returns
    
    returns = returns.reset_index()
    returns = returns.drop(['DTYYYYMMDD'], axis=1)
    
    mean_returns = mean_returns_func(data)
    
    returns_trans = returns.transpose()
    
    industry_filter = industry_func(industry, mean_returns)
    industry1 = pd.get_dummies(industry_filter, columns = ['Value'])
        
    X = np.hstack((returns_trans, mean_returns, industry1))
    
    X = preprocessing.StandardScaler().fit_transform(X)

    clf = DBSCAN(eps=5.3, min_samples=3)
    clf.fit(X)
    clustered = clf.labels_
    
    pairs = extract_pair(returns, clustered)
    pair_rating(pairs, pair_dict)

print(pair_dict)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1736: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:924: RuntimeWarning: divide by zero encountered in log
#   llf = -nobs2*np.log(2*np.pi) - nobs2*np.log(ssr / nobs) - nobs2
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1736: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1736: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1736: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1736: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:924: RuntimeWarning: divide by zero encountered in log
#   llf = -nobs2*np.log(2*np.pi) - nobs2*np.log(ssr / nobs) - nobs2
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:924: RuntimeWarning: divide by zero encountered in log
#   llf = -nobs2*np.log(2*np.pi) - nobs2*np.log(ssr / nobs) - nobs2
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:924: RuntimeWarning: divide by zero encountered in log
#   llf = -nobs2*np.log(2*np.pi) - nobs2*np.log(ssr / nobs) - nobs2
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:924: RuntimeWarning: divide by zero encountered in log
#   llf = -nobs2*np.log(2*np.pi) - nobs2*np.log(ssr / nobs) - nobs2
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1736: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:924: RuntimeWarning: divide by zero encountered in log
#   llf = -nobs2*np.log(2*np.pi) - nobs2*np.log(ssr / nobs) - nobs2
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1736: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1736: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1736: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# {('CAV', 'DHC'): 2, ('CAV', 'DHP'): 2, ('CAV', 'GMC'): 2, ('CAV', 'HAG'): 2, ('CAV', 'HAP'): 1, ('CAV', 'KBC'): 2, ('CAV', 'KDH'): 1, ('CAV', 'LIX'): 2, ('CAV', 'NLG'): 2, ('CAV', 'PAC'): 2, ('CAV', 'PDR'): 2, ('CAV', 'REE'): 2, ('CAV', 'SDN'): 1, ('CAV', 'TCM'): 2, ('CAV', 'TLG'): 1, ('CAV', 'VIC'): 2, ('ACB', 'BVH'): 10, ('ACB', 'DIG'): 7, ('ACB', 'DPM'): 14, ('ACB', 'EIB'): 8, ('ACB', 'GMD'): 10, ('ACB', 'KDC'): 11, ('ACB', 'MBB'): 15, ('ACB', 'MSN'): 12, ('ACB', 'PVT'): 10, ('ACB', 'SHB'): 12, ('ACB', 'STB'): 10, ('ACB', 'VCB'): 13, ('ACB', 'VNM'): 12, ('ACB', 'VSH'): 12, ('BII', 'DLG'): 1, ('BII', 'HAR'): 1, ('BII', 'HQC'): 1, ('BII', 'ITA'): 1, ('BII', 'ITC'): 1, ('BII', 'LCG'): 1, ('BII', 'NBB'): 1, ('BII', 'NTL'): 1, ('BII', 'QCG'): 1, ('BII', 'SCR'): 1, ('BII', 'SJS'): 1, ('BII', 'TDH'): 1, ('DVP', 'GSP'): 5, ('DVP', 'HHG'): 2, ('DVP', 'PJT'): 1, ('DVP', 'PSC'): 3, ('DVP', 'SFI'): 1, ('DVP', 'TCL'): 4, ('DVP', 'VGP'): 1, ('DVP', 'VIP'): 5, ('DVP', 'VNS'): 2, ('DVP', 'VSC'): 1, ('DVP', 'VTO'): 5, ('BTP', 'CNG'): 3, ('BTP', 'DRL'): 3, ('BTP', 'KHP'): 4, ('BTP', 'PGC'): 5, ('BTP', 'PGD'): 1, ('BTP', 'PVG'): 3, ('BTP', 'SBA'): 4, ('BTP', 'SHP'): 3, ('BTP', 'SJD'): 5, ('BTP', 'TBC'): 4, ('C32', 'FCN'): 2, ('C32', 'IDV'): 1, ('C32', 'IJC'): 1, ('C32', 'L10'): 2, ('C32', 'LM8'): 1, ('C32', 'SD6'): 2, ('C32', 'SD9'): 2, ('C32', 'SDT'): 2, ('C32', 'V12'): 2, ('C32', 'VE2'): 1, ('APC', 'CAP'): 2, ('APC', 'HCM'): 4, ('APC', 'LSS'): 1, ('APC', 'SLS'): 1, ('APC', 'SSI'): 4, ('APC', 'VND'): 4, ('APC', 'VTL'): 4, ('DCL', 'DHG'): 2, ('DCL', 'DHT'): 1, ('DCL', 'DMC'): 1, ('DCL', 'IMP'): 4, ('DCL', 'OPC'): 2, ('DCL', 'PPP'): 2, ('DCL', 'TRA'): 4, ('HMC', 'HSG'): 2, ('HMC', 'KKC'): 2, ('HMC', 'PGS'): 1, ('HMC', 'SMC'): 1, ('HMC', 'TLH'): 2, ('HMC', 'VCA'): 1, ('BRC', 'CSM'): 2, ('BRC', 'DPR'): 2, ('BRC', 'DRC'): 2, ('BRC', 'SRC'): 1, ('BRC', 'TNC'): 1, ('BRC', 'TRC'): 2, ('BDB', 'DAE'): 7, ('BDB', 'EBS'): 6, ('BDB', 'EID'): 2, ('BDB', 'HBE'): 5, ('BDB', 'SGD'): 2, ('CMV', 'FDC'): 1, ('CMV', 'FPT'): 1, ('CMV', 'GIL'): 1, ('CMV', 'PET'): 1, ('CMV', 'SVC'): 1, ('DSN', 'OCH'): 1, ('DSN', 'PAN'): 1, ('DSN', 'SGH'): 1, ('DSN', 'SKG'): 2, ('AGR', 'BVS'): 2, ('AGR', 'CTS'): 3, ('AGR', 'SHS'): 1, ('BLF', 'SAM'): 1, ('BLF', 'TS4'): 1, ('AAA', 'BMP'): 2, ('AAA', 'BPC'): 1, ('BCE', 'CII'): 3, ('BCE', 'LHC'): 4, ('KST', 'POT'): 1, ('KST', 'SMT'): 1, ('ACB', 'BID'): 12, ('ACB', 'CTG'): 14, ('ACB', 'DCM'): 12, ('ACB', 'HPG'): 12, ('ACB', 'PNJ'): 9, ('ACB', 'VHC'): 3, ('CAV', 'DQC'): 1, ('CAV', 'HDG'): 1, ('CAV', 'PTB'): 1, ('CAV', 'SFN'): 1, ('CAV', 'TNG'): 1, ('CAV', 'TTF'): 1, ('CAV', 'VTH'): 1, ('C32', 'CTD'): 1, ('C32', 'ICG'): 1, ('C32', 'L43'): 1, ('C32', 'L61'): 1, ('C32', 'LGC'): 1, ('C32', 'SD2'): 1, ('C32', 'SD4'): 1, ('C32', 'SD5'): 1, ('C32', 'VNE'): 1, ('CEO', 'HAR'): 1, ('CEO', 'HQC'): 2, ('CEO', 'ITA'): 2, ('CEO', 'SJS'): 2, ('CEO', 'SZL'): 2, ('CEO', 'TDH'): 3, ('CEO', 'UIC'): 2, ('CEO', 'VPH'): 1, ('CNG', 'DRL'): 3, ('CNG', 'KHP'): 4, ('CNG', 'PGC'): 3, ('CNG', 'PGD'): 1, ('CNG', 'SBA'): 3, ('CNG', 'SHP'): 4, ('CNG', 'SJD'): 4, ('CNG', 'TBC'): 2, ('ALT', 'BDB'): 1, ('ALT', 'DAE'): 2, ('ALT', 'EID'): 2, ('ALT', 'HEV'): 2, ('ALT', 'QST'): 2, ('ALT', 'TPH'): 1, ('APC', 'FMC'): 2, ('APC', 'SGC'): 1, ('APC', 'TAC'): 2, ('DHA', 'HOM'): 1, ('DHA', 'HT1'): 1, ('DHA', 'NNC'): 1, ('DHA', 'VHL'): 1, ('BTT', 'CMS'): 1, ('BTT', 'FPT'): 1, ('BTT', 'PET'): 1, ('GAS', 'PVD'): 6, ('GAS', 'PVS'): 5, ('GAS', 'SJ1'): 1, ('BMC', 'KSB'): 1, ('BMC', 'NBC'): 1, ('BSI', 'BVS'): 3, ('BSI', 'CTS'): 3, ('CLL', 'GSP'): 5, ('CLL', 'VSC'): 5, ('HCM', 'SSI'): 4, ('HCM', 'VND'): 3, ('LAS', 'NFC'): 2, ('LAS', 'SFG'): 1, ('AME', 'C32'): 1, ('AME', 'FCN'): 3, ('AME', 'IDV'): 2, ('AME', 'IJC'): 3, ('AME', 'L10'): 2, ('AME', 'L35'): 2, ('AME', 'L61'): 1, ('AME', 'L62'): 2, ('AME', 'LCD'): 4, ('AME', 'SD2'): 1, ('AME', 'SD5'): 2, ('AME', 'SD6'): 3, ('AME', 'SD9'): 2, ('AME', 'SDT'): 3, ('AME', 'VE8'): 1, ('AME', 'VNE'): 1, ('DHC', 'DHP'): 2, ('DHC', 'HAG'): 1, ('DHC', 'KDH ...
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1736: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1721: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   warnings.warn(

# %%
for pair in pair_dict:
    if pair_dict[pair] > 5:
        print(pair, pair_dict[pair])
# Out:
# ('ACB', 'BVH') 10
# ('ACB', 'DIG') 7
# ('ACB', 'DPM') 14
# ('ACB', 'EIB') 8
# ('ACB', 'GMD') 10
# ('ACB', 'KDC') 11
# ('ACB', 'MBB') 15
# ('ACB', 'MSN') 12
# ('ACB', 'PVT') 10
# ('ACB', 'SHB') 12
# ('ACB', 'STB') 10
# ('ACB', 'VCB') 13
# ('ACB', 'VNM') 12
# ('ACB', 'VSH') 12
# ('BDB', 'DAE') 7
# ('BDB', 'EBS') 6
# ('ACB', 'BID') 12
# ('ACB', 'CTG') 14
# ('ACB', 'DCM') 12
# ('ACB', 'HPG') 12
# ('ACB', 'PNJ') 9
# ('GAS', 'PVD') 6
# ('BDB', 'QST') 6
# ('ACB', 'NT2') 10
# ('CSM', 'DPR') 8
# ('CSM', 'DRC') 8
# ('CSM', 'TRC') 8
# ('ACB', 'MWG') 8
# ('ACB', 'PVI') 10
# ('ASM', 'LHC') 7
# ('DTL', 'PPE') 7
# ('CLM', 'FPT') 8
# ('CLM', 'PET') 8
# ('BSC', 'DSN') 6
# ('ADS', 'DHC') 6
# ('ADS', 'LIX') 6
# ('ACC', 'DHA') 6
# ('ACC', 'NNC') 7
# ('ACC', 'TBX') 6

# %%
import matplotlib.pyplot as plt
#plot each series
# plt.plot(pivot['ACB'], label='ACB', color='orange')
# plt.plot(pivot['MBB'], label='MBB', color='blue')
# plt.plot(pivot['CTG'], label='CTG', color='green')

plt.plot(pivot['BDB'], label='BDB', color='yellow')
plt.plot(pivot['EBS'], label='EBS', color='red')


plt.legend(title='Ticker')

#add axes labels and a title
plt.ylabel('% Change', fontsize=14)
plt.xlabel('Time', fontsize=14)
plt.title('% Change Time Series of 3 Cointegrated Stocks', fontsize=16)

#display plot
plt.show()
